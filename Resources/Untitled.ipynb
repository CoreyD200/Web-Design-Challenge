# %%
import pandas as pd
import csv

# %%
file= "WeatherData.csv"

# %%
cities_df= pd.read_csv(file)

# %%
cities_df[["City","Cloudiness","Country", "Humidity","Lat","Lng","Max Temp","Wind Speed"]]
# Out:
#              City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0          Avarua         100      CK        88 -21.21 -159.78     80.60
# 1      Chokurdakh         100      RU        96  70.63  147.92    -18.56
# 2          Albany          90      US        80  42.60  -73.97     39.00
# 3         Isangel          82      VU        88 -19.55  169.27     73.40
# 4       Cape Town          40      ZA        49 -33.93   18.42     71.01
# ..            ...         ...     ...       ...    ...     ...       ...
# 559    Lavrentiya           0      RU        78  65.58 -171.00    -14.44
# 560   La Macarena         100      CO        41   2.18  -73.78     88.54
# 561       Mildura           0      AU        40 -34.20  142.15     73.40
# 562        Tiznit           0      MA        47  29.58   -9.50     57.20
# 563  Mersa Matruh         100      EG        66  31.35   27.25     57.45
#
#      Wind Speed
# 0         11.41
# 1          4.72
# 2          6.93
# 3          2.24
# ...

# %%
print (cities_df[["City","Cloudiness","Country", "Humidity","Lat","Lng","Max Temp","Wind Speed"]].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Avarua</td>
#       <td>100</td>
#       <td>CK</td>
#       <td>88</td>
#       <td>-21.21</td>
#       <td>-159.78</td>
#       <td>80.60</td>
#       <td>11.41</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Chokurdakh</td>
#       <td>100</td>
#       <td>RU</td>
#       <td>96</td>
#       <td>70.63</td>
#       <td>147.92</td>
#       <td>-18.56</td>
#       <td>4.72</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albany</td>
#       <td>90</td>
#       <td>US</td>
#       <td>80</td>
#       <td>42.60</td>
#       <td>-73.97</td>
#       <td>39.00</td>
#       <td>6.93</td>
# ...
